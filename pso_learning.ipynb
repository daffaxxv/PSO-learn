# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pso import *

# %%
time = np.arange(0,100,.1)
a = 1
b = -50
c = -30

yd = a*time**2+b*time+c

coeff = optimize(yd, time = time, bound = np.array([0,50]), vel_init = 2, maxiter = 50)
print([a,b,c])
print(coeff)
# Out:
# [1, -50, -30]
# [  1.04878003 -55.56919989 112.71908167]
