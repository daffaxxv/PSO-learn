# %%
from pso import *

t = np.arange(0,20,.01)

a = .5
b = 2
c = 2.1
d = 3
# yd = a*t**2+b*t+c # try using quadratic function
# yd = a*t**3+b*t**2+c*t+d # try using cubic function
yd = a*np.sin(t*b) + c*np.cos(t*d) #try using periodic function

coeff1 = optimize(yd, swarm_size = np.array([5,200]), time = t, c = np.array([1.5,1.5]), bound = np.array([0,50]), vel_init = 5, maxiter = 50, func = 'fourier', etol = 1e-5)

print(coeff1)
# Out:
# Please make the swarm_size = [odd number (not 1),n]
# [ 7.09460543e-04 -1.78113473e-04  5.00580311e-01  2.10157230e+00
#   6.62324532e-04]
